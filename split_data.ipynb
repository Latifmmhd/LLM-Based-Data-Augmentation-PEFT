# %% [markdown]
# <a href="https://colab.research.google.com/github/Latifmmhd/Augmentasi-Data-Indonesia-Tweet/blob/main/split_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip dataset.zip
# Out:
# Archive:  dataset.zip
#    creating: dataset/
#    creating: dataset/.ipynb_checkpoints/
#   inflating: dataset/.ipynb_checkpoints/get_data_info-checkpoint.ipynb
#   inflating: dataset/all_data_augmented_bnf16.csv
#   inflating: dataset/get_data_info.ipynb

# %%
# %cd ..
# Out:
# /content

# %%
from datasets import load_dataset, Dataset, DatasetDict
from sklearn.model_selection import train_test_split

# %%
# !pip install -q gdown
import gdown
import pandas as pd

# Google Drive file ID
file_id = "1BKEZGdCkm9_S_-zWkD2cUXziabL9eE5Y"
output = "all_data_augmented_bnf16.csv"

# Download file
gdown.download(f"https://drive.google.com/uc?id={file_id}", output, quiet=False)
print(f"Dataset downloaded: {output}")

# Convert to pandas DataFrame for easy splitting
df = pd.read_csv(output)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1BKEZGdCkm9_S_-zWkD2cUXziabL9eE5Y
# To: /content/all_data.csv
# 100%|██████████| 1.38M/1.38M [00:00<00:00, 11.6MB/s]
# Dataset downloaded: all_data.csv

# %%
df
# Out:
#        index                                              tweet    label
# 0          0                        pagi2 udah di buat emosi :)    anger
# 1          1  kok stabilitas negara, memange 10 thn negara t...    anger
# 2          2                       dah lah emosi mulu liat emyu    anger
# 3          3  aib? bodoh benar! sebelum kata aib itu muncul,...    anger
# 4          4                            dih lu yg nyebelin bego    anger
# ...      ...                                                ...      ...
# 12595  12595  ga usah repot-repot ngebalas dendam, cukup maa...  neutral
# 12596  12596  bappenas akui, ketika mereka berada di lokasi ...  neutral
# 12597  12597  energi sebaiknya digunakan untuk berpikir krit...  neutral
# 12598  12598  semua yang dimulai dengan rasa marah, akan ber...  neutral
# 12599  12599  aku paham, kamu cuma mau ditanggapi dan disupp...  neutral
#
# [12600 rows x 3 columns]

# %%
# Split into train and temp (which will be further split into val and test)
train_df, temp_df = train_test_split(df, test_size=0.3, random_state=42)

# Split temp into validation and test sets
val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)

# %%
# Save each DataFrame to CSV
train_df.to_csv('dataset/train.csv', index=False)
val_df.to_csv('dataset/val.csv', index=False)
test_df.to_csv('dataset/test.csv', index=False)

# %%
# !zip -r dataset.zip dataset/
# Out:
#   adding: dataset/ (stored 0%)
#   adding: dataset/train.csv (deflated 60%)
#   adding: dataset/all_data_augmented_bnf16.csv (deflated 63%)
#   adding: dataset/.ipynb_checkpoints/ (stored 0%)
#   adding: dataset/.ipynb_checkpoints/get_data_info-checkpoint.ipynb (deflated 23%)
#   adding: dataset/val.csv (deflated 59%)
#   adding: dataset/test.csv (deflated 59%)
#   adding: dataset/get_data_info.ipynb (deflated 50%)

# %%
from google.colab import files
files.download('dataset.zip')
